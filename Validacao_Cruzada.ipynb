# %% [markdown]
# <a href="https://colab.research.google.com/github/Carlos-Egger/cross-validation/blob/main/Validacao_Cruzada.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikeras

# %%
import pandas as pd
import tensorflow as tf
import sklearn
import scikeras

# %%
tf.__version__, sklearn.__version__, scikeras.__version__
# Out:
# ('2.17.0', '1.5.2', '0.13.0')

# %%
from scikeras.wrappers import KerasClassifier
from sklearn.model_selection import cross_val_score
from tensorflow.keras.models import Sequential
from tensorflow.keras import backend as k

# %%
X = pd.read_csv('/content/entradas_breast.csv')
y = pd.read_csv('/content/saidas_breast.csv')

# %%
def criar_rede():
  k.clear_session()
  rede_neural = Sequential([
      tf.keras.layers.InputLayer(shape = (30,)),
      tf.keras.layers.Dense(units = 16, activation='relu', kernel_initializer='RandomUniform' ),
      tf.keras.layers.Dense(units = 16, activation='relu', kernel_initializer='RandomUniform' ),
      tf.keras.layers.Dense(units = 1, activation='sigmoid'),
  ])
  otimizador = tf.keras.optimizers.Adam(learning_rate=0.001, clipvalue=0.5)
  rede_neural.compile(optimizer = otimizador, loss = 'binary_crossentropy', metrics =['binary_accuracy'])
  return rede_neural

# %%
rede_neural = KerasClassifier(model = criar_rede, epochs = 100, batch_size=10)

# %%
resultados = cross_val_score(estimator = rede_neural, X = X, y = y, cv = 10, scoring = 'accuracy')
# Out:
# Epoch 1/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - binary_accuracy: 0.5534 - loss: 1.3148
# Epoch 2/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.6569 - loss: 0.5853
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - binary_accuracy: 0.7376 - loss: 0.4758
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.7451 - loss: 0.5322
# Epoch 5/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - binary_accuracy: 0.8282 - loss: 0.4083
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - binary_accuracy: 0.7961 - loss: 0.5294
# Epoch 7/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8184 - loss: 0.3876
# Epoch 8/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - binary_accuracy: 0.7944 - loss: 0.4959
# Epoch 9/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.8481 - loss: 0.3776
# Epoch 10/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - binary_accuracy: 0.8549 - loss: 0.3691
# Epoch 11/100
# ...

# %%
resultados
# Out:
# array([0.73684211, 0.75438596, 0.87719298, 0.8245614 , 0.73684211,
#        0.84210526, 0.8245614 , 0.77192982, 0.68421053, 0.89285714])

# %%
resultados.mean()
# Out:
# 0.7945488721804511

# %%
resultados.std()
# Out:
# 0.06443372745902261
